# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Deep Learning
# ## Project: Build a Digit Recognition Program
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ----
# ## Step 1: Design and Test a Model Architecture
# Design and implement a deep learning model that learns to recognize sequences of digits. Train the model using synthetic data generated by concatenating character images from [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) or [MNIST](http://yann.lecun.com/exdb/mnist/). To produce a synthetic sequence of digits for testing, you can for example limit yourself to sequences up to five digits, and use five classifiers on top of your deep network. You would have to incorporate an additional ‘blank’ character to account for shorter number sequences.
#
# There are various aspects to consider when thinking about this problem:
# - Your model can be derived from a deep neural net or a convolutional network.
# - You could experiment sharing or not the weights between the softmax classifiers.
# - You can also use a recurrent network in your deep neural net to replace the classification layers and directly emit the sequence of digits one-at-a-time.
#
# Here is an example of a [published baseline model on this problem](http://static.googleusercontent.com/media/research.google.com/en//pubs/archive/42241.pdf). ([video](https://www.youtube.com/watch?v=vGPI_JvLoN0))

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
import struct
from array import array

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

#We use Struct to unpack the binary data structure
def load(path_img, path_lbl):
        with open(path_lbl, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))
            if magic != 2049:
                raise ValueError('Expected 2049 got {}'.format(magic))
            labels = array("B", file.read())

        with open(path_img, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))
            if magic != 2051:
                raise ValueError('Expected 2051 got {}'.format(magic))

            image_data = array("B", file.read())

        images = []
        print("loaind {} images".format(size))
        for i in range(size):
            images.append([0] * rows * cols)

        for i in range(size):
            images[i][:] = image_data[i*rows*cols:(i + 1) * rows * cols]

        return images, labels

train_dataset, train_labels = load('train-images-idx3-ubyte','train-labels-idx1-ubyte')
test_dataset, test_labels = load('t10k-images-idx3-ubyte','t10k-labels-idx1-ubyte')
# Out:
# loaind 60000 images
# loaind 10000 images

# %%
from sklearn.model_selection import train_test_split
train, validation, t_labels, v_labels = train_test_split(train_dataset, train_labels, test_size=0.33, random_state=42)

# %%
index = 999
img = np.asarray(train[index]).reshape(28,28)
plt.imshow(img)
print(img.shape)
print(bytes(t_labels[index]).decode('utf-8'))
# Out:
# (28, 28)
# 3

# %%
def concat_images(imga, imgb):
    ha,wa = imga.shape[:2]
    hb,wb = imgb.shape[:2]
    max_height = np.max([ha, hb])
    total_width = wa+wb
    new_img = np.zeros(shape=(max_height, total_width, 3), dtype=np.uint8)
    new_img[:ha,:wa]=imga
    new_img[:hb,wa:wa+wb]=imgb
    return new_img

# %%
from scipy import ndimage
from scipy.misc import imresize
import random

IMAGE_SIZE = 28
NUM_CHANNELS = 1
NUM_LABELS = 11 # 0-9 and no digit (10)
N = 5 # max number of digits on the sequence

np.random.seed(42)
  
def create_sequences(images, labels):
  
  #if type(train_labels[0]).__module__ == np.__name__:
  #  print('Sequence already created')
  #  return images, labels
  
  length = len(images)
  index = 0
  seq_images = np.ndarray([length,IMAGE_SIZE,IMAGE_SIZE*N,NUM_CHANNELS], dtype='float32')
  seq_labels = np.ones([length, N], dtype=int) * 10 # init to 10 cause it would be no digit
  black = np.asarray([[0]*IMAGE_SIZE for _ in range (0,IMAGE_SIZE)])
  black = (black/125.5)-1
  while index < length:
    # Random
    L = random.randint(1, N)
    # Image
    selected = []
    for k in range(0,N-L):
        selected.append(black)
    i=0
    while i<L:
        offset = random.randint(0, length-N)
        im = np.asarray(images[offset]).reshape(28,28)
        im = (im/125.5)-1
        selected.append(im)
        seq_labels[index,N-L+i]=labels[offset]
        i=i+1
    sequence = np.hstack(selected)
    sequence_resized = imresize(sequence, (28,28*N)) #28x28
    sequence_resized = sequence_resized.reshape((28, 28*N, NUM_CHANNELS)).astype(np.float32) #28x28x1
    
    seq_images[index] = sequence_resized
      
    index += 1
      
  return seq_images, seq_labels

# %%
strain_dataset, st_labels = create_sequences(train, t_labels)
svalid_dataset, sv_labels = create_sequences(validation, v_labels)

stest_dataset,stest_labels = create_sequences(test_dataset,test_labels)

# %%
index = 11
print(sv_labels[index])
im = svalid_dataset[index].reshape(28,28*N)
plt.imshow(im,cmap='gray')
plt.show()
#test_dataset, test_labels = create_sequences(test_dataset, test_labels)

#print('Training set', strain_dataset.shape, st_labels.shape)
#print('Validation set', valid_dataset.shape, valid_labels.shape)
#print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# [10 10  8  1  9]

# %% [markdown]
# Creating the Convolutional Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D,Flatten,Dropout,Input
from keras.layers.pooling import MaxPooling2D
from keras.models import load_model
from IPython.display import SVG
from keras.models import Model
from keras.utils.np_utils import to_categorical
try:
    model = load_model("mnist_cnn.h5")
except:
    model = None
x = Input((28, 28*N,1))

#model.add(Dense(output_dim=64, input_dim=100))
y = Convolution2D(8, 3, 3, activation="relu", border_mode="same")(x)
#y = Convolution2D(32, 3, 3, activation="relu")(y)
y = MaxPooling2D((2, 2))(y)
#y = Dropout(0.25)(y)

y = Convolution2D(16, 3, 3, border_mode="same", activation="relu")(y)
#y = Convolution2D(64, 3, 3, activation="relu")(y)
y = MaxPooling2D((2, 2))(y)
#y = Dropout(0.25)(y)


y = Flatten()(y)
y = Dense(128, activation="relu")(y)

digit1 = Dense(11, activation="softmax")(y)
digit2 = Dense(11, activation="softmax")(y)
digit3 = Dense(11, activation="softmax")(y)
digit4 = Dense(11, activation="softmax")(y)
digit5 = Dense(11, activation="softmax")(y)
if not model:
    model = Model(input=x, output=[digit1, digit2, digit3,digit4,digit5])
    model.compile(optimizer='adam',
          loss='categorical_crossentropy',
          metrics=['accuracy'])
print(model.layers[0].output_shape)
print(model.layers[1].output_shape)
print(model.layers[2].output_shape)
print(model.layers[3].output_shape)
print(model.layers[4].output_shape)

train_labels = [to_categorical(st_labels[:,0],11),
                to_categorical(st_labels[:,1],11),
                to_categorical(st_labels[:,2],11),
                to_categorical(st_labels[:,3],11),
                to_categorical(st_labels[:,4],11)]
validation_labels = [to_categorical(sv_labels[:,0],11),
                     to_categorical(sv_labels[:,1],11),
                     to_categorical(sv_labels[:,2],11),
                     to_categorical(sv_labels[:,3],11),
                     to_categorical(sv_labels[:,4],11)]

#print(len(train_labels[0]))
#print(sv_train.shape)

model.fit(strain_dataset, train_labels, nb_epoch=3, batch_size=64,validation_data=(svalid_dataset, validation_labels))
# Out:
# (None, 28, 140, 1)
# (None, 28, 140, 8)
# (None, 14, 70, 8)
# (None, 14, 70, 16)
# (None, 7, 35, 16)
# Train on 40200 samples, validate on 19800 samples
# Epoch 1/3
# 40200/40200 [==============================] - 103s - loss: 9.7578 - dense_8_loss: 0.8468 - dense_9_loss: 1.3950 - dense_10_loss: 2.1822 - dense_11_loss: 2.9166 - dense_12_loss: 2.4172 - dense_8_acc: 0.9003 - dense_9_acc: 0.8428 - dense_10_acc: 0.7738 - dense_11_acc: 0.7152 - dense_12_acc: 0.7351 - val_loss: 0.7758 - val_dense_8_loss: 0.0880 - val_dense_9_loss: 0.1414 - val_dense_10_loss: 0.1560 - val_dense_11_loss: 0.1947 - val_dense_12_loss: 0.1957 - val_dense_8_acc: 0.9739 - val_dense_9_acc: 0.9551 - val_dense_10_acc: 0.9516 - val_dense_11_acc: 0.9394 - val_dense_12_acc: 0.9381
# Epoch 2/3
# 40200/40200 [==============================] - 103s - loss: 0.4760 - dense_8_loss: 0.0511 - dense_9_loss: 0.0793 - dense_10_loss: 0.0997 - dense_11_loss: 0.1161 - dense_12_loss: 0.1299 - dense_8_acc: 0.9847 - dense_9_acc: 0.9758 - dense_10_acc: 0.9689 - dense_11_acc: 0.9629 - dense_12_acc: 0.9582 - val_loss: 0.6037 - val_dense_8_loss: 0.0666 - val_dense_9_loss: 0.1136 - val_dense_10_loss: 0.1090 - val_dense_11_loss: 0.1543 - val_dense_12_loss: 0.1601 - val_dense_8_acc: 0.9810 - val_dense_9_acc: 0.9652 - val_dense_10_acc: 0.9669 - val_dense_11_acc: 0.9527 - val_dense_12_acc: 0.9498
# Epoch 3/3
# 40200/40200 [==============================] - 100s - loss: 0.2286 - dense_8_loss: 0.0237 - dense_9_loss: 0.0345 - dense_10_loss: 0.0494 - dense_11_loss: 0.0575 - dense_12_loss: 0.0635 - dense_8_acc: 0.9927 - dense_9_acc: 0.9880 - dense_10_acc: 0.9844 - dense_11_acc: 0.9812 - dense_12_acc: 0.9791 - val_loss: 0.5746 - val_dense_8_loss: 0.0589 - val_dense_9_loss: 0.0919 - val_dense_10_loss: 0.1106 - val_dense_11_loss: 0.1709 - val_dense_12_loss: 0.1424 - val_dense_8_acc: 0.9840 - val_dense_9_acc: 0.9761 - val_dense_10_acc: 0.9692 - val_dense_11_acc: 0.9553 - val_dense_12_acc: 0.9577

# %%
model.save("mnist_cnn.h5")

# %%
SeqTest_lbels = [to_categorical(stest_labels[:,0],11),
                 to_categorical(stest_labels[:,1],11),
                 to_categorical(stest_labels[:,2],11),
                 to_categorical(stest_labels[:,3],11),
                 to_categorical(stest_labels[:,4],11)]

model.evaluate(stest_dataset,SeqTest_lbels)
# Out:
#  9952/10000 [============================>.] - ETA: 0s
# [0.39994703732430936,
#  0.0422314773248414,
#  0.065638248844465119,
#  0.08960258271168714,
#  0.088445834722544539,
#  0.11402889425263274,
#  0.99029999999999996,
#  0.98399999999999999,
#  0.97789999999999999,
#  0.97519999999999996,
#  0.96970000000000001]

# %% [markdown]
# ### Question 1
# _What approach did you take in coming up with a solution to this problem?_

# %% [markdown]
# **Answer:**
# At first I wondered if it was better to approach the problem through a network capable of recognizing a single digit and use it through a sliding window in order to identify sequence of digits. I have seen that in literature the problem has instead been solved through convolutional neural networ capable of extracting each digit as a single feature of the same network.

# %% [markdown]
# ### Question 2
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)_

# %% [markdown]
# **Answer:**
# I have used a CNN with three layers made by a Convolutional layer, pooling and normalization.
# The input image is (28,28), after the first convolutional layer we have 16 filters (12,12) each. After the second convolutional layer we have 32 filters (6,6) each. After the third convolutional layer we have 64 filters of size 1 each. Create a Dense layer of 64 nodes x 10 labels for each feature and connect each dense layer with each of the 64 filters. This gives us the five logits we can use to calculate the loss against the desired labels through the sparse_softmax_cross_entropy_with_logits function. We can the sum the 5 loss values and try to optimize the model in order to minimize the loss through the AdagradOptimizer.

# %% [markdown]
# ### Question 3
# _How did you train your model? How did you generate your synthetic dataset?_ Include examples of images from the synthetic data you constructed.

# %% [markdown]
# **Answer:**
# I created a dataset of sequences, with a max of 5 digits, by randomly concatenating single MNIST digit, along with the image i created a vector of 5 integers representing the actual value the netwrok has to learn. I created three sets of images: one for training, one for validation and the last for testing. The model has been trained with batches of 64 images/labels a time and validated consequently.

# %%
index = 22
print(stest_labels[index])
im = stest_dataset[index].reshape(28,28*N)
plt.imshow(im,cmap='gray')
plt.show()
array = [im.reshape(1,28,28*N,1)]
# Out:
# [4 1 2 2 0]

# %%
y_pred = model.predict(array,batch_size=1,verbose=0)
print(y_pred)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)))
# Out:
# [array([[  1.89773459e-08,   3.96718997e-06,   5.16125418e-08,
#           6.70689957e-08,   9.99591768e-01,   5.77989567e-06,
#           2.75028666e-04,   1.45751846e-08,   6.97493689e-08,
#           1.19584125e-04,   3.59107844e-06]], dtype=float32), array([[  9.77087282e-08,   9.99929905e-01,   1.29717064e-08,
#           3.49003881e-11,   5.43213389e-07,   1.95502794e-12,
#           2.31272566e-08,   1.06869010e-07,   6.90195375e-05,
#           1.57537045e-07,   1.32939505e-07]], dtype=float32), array([[  1.27736770e-13,   6.79879677e-12,   9.99999881e-01,
#           7.33675520e-08,   1.03594498e-12,   1.82111352e-13,
#           6.20695528e-18,   3.81476006e-09,   1.24995473e-13,
#           1.52026362e-12,   3.13386805e-17]], dtype=float32), array([[  5.07585196e-10,   4.94896852e-08,   9.99976277e-01,
#           2.32445000e-05,   9.88802484e-10,   1.25930100e-09,
#           1.24608214e-11,   3.79612175e-07,   8.29014288e-12,
#           8.06305493e-08,   3.32850499e-19]], dtype=float32), array([[  1.00000000e+00,   1.95321811e-17,   4.52161705e-14,
#           3.40124622e-19,   5.36035569e-17,   2.99304608e-13,
#           2.17319381e-14,   1.61521328e-12,   9.13704117e-13,
#           3.74617568e-12,   0.00000000e+00]], dtype=float32)]
# 4
# 1
# 2
# 2
# 0

# %% [markdown]
# ----
# ## Step 2: Train a Model on a Realistic Dataset
# Once you have settled on a good architecture, you can train your model on real data. In particular, the [Street View House Numbers (SVHN)](http://ufldl.stanford.edu/housenumbers/) dataset is a good large-scale dataset collected from house numbers in Google Street View. Training on this more challenging dataset, where the digits are not neatly lined-up and have various skews, fonts and colors, likely means you have to do some hyperparameter exploration to perform well.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
import h5py

class DigitStructFile:
    def __init__(self, inf):
        self.inf = h5py.File(inf, 'r')
        self.digitStructName = self.inf['digitStruct']['name']
        self.digitStructBbox = self.inf['digitStruct']['bbox']
        
    def getName(self,n):
        return ''.join([chr(c[0]) for c in self.inf[self.digitStructName[n][0]].value])

    def bboxHelper(self,attr):
        if (len(attr) > 1):
            attr = [self.inf[attr.value[j].item()].value[0][0] for j in range(len(attr))]
        else:
            attr = [attr.value[0][0]]
        return attr

    def getBbox(self,n):
        bbox = {}
        bb = self.digitStructBbox[n].item()
        bbox['height'] = self.bboxHelper(self.inf[bb]["height"])
        bbox['label'] = self.bboxHelper(self.inf[bb]["label"])
        bbox['left'] = self.bboxHelper(self.inf[bb]["left"])
        bbox['top'] = self.bboxHelper(self.inf[bb]["top"])
        bbox['width'] = self.bboxHelper(self.inf[bb]["width"])
        return bbox

    def getDigitStructure(self,n):
        print (" \r%d" % n ,end="")
        s = self.getBbox(n)
        s['name']=self.getName(n)
        return s

    def getAllDigitStructure(self):
        return [self.getDigitStructure(i) for i in range(len(self.digitStructName))]
    
    def getAllDigitStructure_ByDigit(self):
        print("Loading...")
        pictDat = self.getAllDigitStructure()
        result = []
        structCnt = 1
        for i in range(len(pictDat)):
            print (" \r%d" % i ,end="")
            item = { 'filename' : pictDat[i]["name"] }
            figures = []
            for j in range(len(pictDat[i]['height'])):
               figure = {}
               figure['height'] = pictDat[i]['height'][j]
               figure['label']  = pictDat[i]['label'][j]
               figure['left']   = pictDat[i]['left'][j]
               figure['top']    = pictDat[i]['top'][j]
               figure['width']  = pictDat[i]['width'][j]
               figures.append(figure)
            structCnt = structCnt + 1
            item['boxes'] = figures
            result.append(item)
        return result

# %%
train_folders = 'sv_train/train'
test_folders = 'test'
extra_folders = 'extra'
fin = os.path.join(train_folders, 'digitStruct.mat')
dsf = DigitStructFile(fin)
train_data = dsf.getAllDigitStructure_ByDigit()
# Out:
# Loading...
# 33401

# %%
from PIL import Image
from PIL import ImageFilter
import random
train_folders = 'sv_train/train'
test_folders = 'test'
extra_folders = 'extra'
SV_IMG_SIZE = 60
SV_CHANNELS = 3
train_imsize = np.ndarray([len(train_data),2])
k = 500
sv_images = []
max_images = 20000#len(train_data)
max_digits = 5
sv_labels = np.ones([max_images, max_digits], dtype=int) * 0 # init to 10 cause it would be no digit
nboxes = [[] for i in range(max_images)]
print ("%d to load" % len(train_data))
def getBBox(i,perc):
    '''
    Given i, the desired i.png, returns
    x_min, y_min, x_max, y_max,
    the four numbers which define the small rectangular bounding
    box that contains all individual character bounding boxes
    '''
    boxes = train_data[i]['boxes'] 
    x_min=9990
    y_min=9990
    x_max=0
    y_max=0
    for bid,b in enumerate(boxes):
        x_min = b['left'] if b['left'] <= x_min else x_min
        y_min = b['top'] if b['top'] <= y_min else y_min
        x_max = b['left']+b['width'] if  b['left']+b['width'] >= x_max else x_max
        y_max = b['top']+b['height'] if b['top']+b['height'] >= y_max else y_max
    step_x = 0 #random.random()/2*x_min
    step_y = 0 #random.random()/2*y_min
    dy = y_max-y_min
    dx = x_max-x_min
    dpy = dy*perc
    dpx = dx*perc
    nboxes[i]=[dpx+step_x,dpy+step_y,dx,dy]
    return x_min-dpx-step_x, y_min-dpy-step_y, x_max+dpx, y_max+dpy

for i in range(max_images):
    
    print (" \r%d" % i ,end="")
    filename = train_data[i]['filename']
    fullname = os.path.join(train_folders, filename)
    boxes = train_data[i]['boxes']
    label = [0,0,0,0,0]
    lb = len(boxes)
    if lb <= max_digits:
        im = Image.open(fullname)
        x_min, y_min, x_max, y_max = getBBox(i,0.3)
        nxmax = x_max# if x_max > SV_IMG_SIZE else SV_IMG_SIZE
        nymax = y_max #if y_max > SV_IMG_SIZE else SV_IMG_SIZE
        im = im.crop([x_min,y_min,nxmax,nymax])
        owidth, oheight = im.size
        wr = SV_IMG_SIZE/float(owidth)
        hr = SV_IMG_SIZE/float(oheight)
        for bid,box in  enumerate(boxes):
            sv_labels[i][max_digits-lb+bid] = int(box['label']) 
        box = nboxes[i]
        box[0]*=wr
        box[1]*=hr
        box[2]*=wr
        box[3]*=hr
        im = im.resize((SV_IMG_SIZE,SV_IMG_SIZE),Image.ANTIALIAS)
        #im = im.filter(ImageFilter.EDGE_ENHANCE_MORE)
        im = im - np.mean(im)
        array = np.asarray(im)
        array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,SV_CHANNELS)).astype(np.float32)
        na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE,1],dtype=int)
        for x in range (array.shape[0]):
            for y in range (array.shape[1]):
                na[x][y]=np.average(array[x][y][:])
        na = na.reshape(SV_IMG_SIZE,SV_IMG_SIZE,1)
        na = na.astype(np.float32)
        na = (na/125.5)-1
        #na = na - np.mean(na)
        #print(array.shape)
        sv_images.append(na)

#plt.imshow(sv_images[0])
# Out:
# 33402 to load
# 19999

# %%
from matplotlib import patches
idx =8
sv_images = np.asarray(sv_images)
fig,ax = plt.subplots(1)

ax.imshow(sv_images[idx].reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
#plt.imshow(sv_images[idx].reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
box = nboxes[idx]
rect = patches.Rectangle((box[0],box[1]),box[2],box[3],linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
print(sv_labels[idx])
# Out:
# [0 0 1 2 8]

# %%
## from sklearn.model_selection import train_test_split
sv_train, sv_validation, svt_labels, svv_labels = train_test_split(sv_images, sv_labels, test_size=0.33, random_state=42)

# %%
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Activation, Convolution2D,Flatten,Dropout,Input
from keras.layers.pooling import MaxPooling2D
#from keras.utils.visualize_util import plot
from IPython.display import SVG
from keras.models import Model
adam = Adam(lr=1)
SV_CHANNELS=1

try:
    model = load_model("cnn_recog.h5")
except:
    model = None
    
x = Input((SV_IMG_SIZE, SV_IMG_SIZE,SV_CHANNELS))
y = Convolution2D(4, 3, 3, activation='relu', border_mode='valid')(x)#y = MaxPooling2D((2, 2))(y)
y = Convolution2D(8, 3, 3, activation='relu', border_mode='valid')(y)
y = MaxPooling2D((2, 2))(y)
y = Dropout(0.25)(y)
y = Convolution2D(16, 3, 3, activation='relu', border_mode='valid')(y)
y = MaxPooling2D((2, 2))(y)
y = Flatten()(y)
y = Dense(128, activation='relu')(y)


digit1 = Dense(11, activation="softmax")(y)
digit2 = Dense(11, activation="softmax")(y)
digit3 = Dense(11, activation="softmax")(y)
digit4 = Dense(11, activation="softmax")(y)
digit5 = Dense(11, activation="softmax")(y)

if not model:
    model = Model(input=x, output=[digit1, digit2, digit3,digit4,digit5])
    model.compile(optimizer='adam',
          loss='categorical_crossentropy',
          metrics=['accuracy'])
    #model.summary()
sv_train_labels = [to_categorical(svt_labels[:,0],11),
                   to_categorical(svt_labels[:,1],11),
                   to_categorical(svt_labels[:,2],11),
                   to_categorical(svt_labels[:,3],11),
                   to_categorical(svt_labels[:,4],11)]
sv_validation_labels = [to_categorical(svv_labels[:,0],11),
                        to_categorical(svv_labels[:,1],11),
                        to_categorical(svv_labels[:,2],11),
                        to_categorical(svv_labels[:,3],11),
                        to_categorical(svv_labels[:,4],11)]

model.fit(sv_train, sv_train_labels, nb_epoch=30, batch_size=32,validation_data=(sv_validation, sv_validation_labels))
# Out:
# Train on 13400 samples, validate on 6600 samples
# Epoch 1/30
# 13400/13400 [==============================] - 64s - loss: 5.6277 - dense_306_loss: 0.0138 - dense_307_loss: 0.2218 - dense_308_loss: 0.9934 - dense_309_loss: 2.1280 - dense_310_loss: 2.2707 - dense_306_acc: 0.9975 - dense_307_acc: 0.9557 - dense_308_acc: 0.7194 - dense_309_acc: 0.2650 - dense_310_acc: 0.1562 - val_loss: 5.1529 - val_dense_306_loss: 0.0172 - val_dense_307_loss: 0.2654 - val_dense_308_loss: 0.9038 - val_dense_309_loss: 1.8699 - val_dense_310_loss: 2.0966 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9562 - val_dense_308_acc: 0.7752 - val_dense_309_acc: 0.3645 - val_dense_310_acc: 0.2792
# Epoch 2/30
# 13400/13400 [==============================] - 53s - loss: 4.2812 - dense_306_loss: 0.0027 - dense_307_loss: 0.1546 - dense_308_loss: 0.7063 - dense_309_loss: 1.6128 - dense_310_loss: 1.8048 - dense_306_acc: 0.9998 - dense_307_acc: 0.9592 - dense_308_acc: 0.7931 - dense_309_acc: 0.4722 - dense_310_acc: 0.3874 - val_loss: 3.8559 - val_dense_306_loss: 0.0059 - val_dense_307_loss: 0.1720 - val_dense_308_loss: 0.6838 - val_dense_309_loss: 1.4607 - val_dense_310_loss: 1.5334 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9588 - val_dense_308_acc: 0.8167 - val_dense_309_acc: 0.5423 - val_dense_310_acc: 0.4980
# Epoch 3/30
# 13400/13400 [==============================] - 51s - loss: 3.3475 - dense_306_loss: 0.0020 - dense_307_loss: 0.1210 - dense_308_loss: 0.5692 - dense_309_loss: 1.2895 - dense_310_loss: 1.3658 - dense_306_acc: 0.9998 - dense_307_acc: 0.9663 - dense_308_acc: 0.8333 - dense_309_acc: 0.5830 - dense_310_acc: 0.5472 - val_loss: 3.0577 - val_dense_306_loss: 0.0022 - val_dense_307_loss: 0.1184 - val_dense_308_loss: 0.5260 - val_dense_309_loss: 1.2085 - val_dense_310_loss: 1.2026 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9682 - val_dense_308_acc: 0.8377 - val_dense_309_acc: 0.6091 - val_dense_310_acc: 0.6145
# Epoch 4/30
# 13400/13400 [==============================] - 52s - loss: 2.8011 - dense_306_loss: 0.0016 - dense_307_loss: 0.1009 - dense_308_loss: 0.4940 - dense_309_loss: 1.0882 - dense_310_loss: 1.1165 - dense_306_acc: 0.9998 - dense_307_acc: 0.9701 - dense_308_acc: 0.8546 - dense_309_acc: 0.6484 - dense_310_acc: 0.6349 - val_loss: 2.8206 - val_dense_306_loss: 0.0026 - val_dense_307_loss: 0.1126 - val_dense_308_loss: 0.5226 - val_dense_309_loss: 1.1314 - val_dense_310_loss: 1.0515 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9700 - val_dense_308_acc: 0.8456 - val_dense_309_acc: 0.6474 - val_dense_310_acc: 0.6639
# Epoch 5/30
# 13400/13400 [==============================] - 56s - loss: 2.4470 - dense_306_loss: 0.0013 - dense_307_loss: 0.0851 - dense_308_loss: 0.4385 - dense_309_loss: 0.9436 - dense_310_loss: 0.9786 - dense_306_acc: 0.9998 - dense_307_acc: 0.9762 - dense_308_acc: 0.8674 - dense_309_acc: 0.6975 - dense_310_acc: 0.6808 - val_loss: 2.5570 - val_dense_306_loss: 0.0022 - val_dense_307_loss: 0.1002 - val_dense_308_loss: 0.4799 - val_dense_309_loss: 1.0019 - val_dense_310_loss: 0.9728 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9711 - val_dense_308_acc: 0.8568 - val_dense_309_acc: 0.6808 - val_dense_310_acc: 0.6836
# Epoch 6/30
# 13400/13400 [==============================] - 53s - loss: 2.2082 - dense_306_loss: 0.0011 - dense_307_loss: 0.0760 - dense_308_loss: 0.4028 - dense_309_loss: 0.8422 - dense_310_loss: 0.8861 - dense_306_acc: 0.9997 - dense_307_acc: 0.9775 - dense_308_acc: 0.8766 - dense_309_acc: 0.7302 - dense_310_acc: 0.7081 - val_loss: 2.3813 - val_dense_306_loss: 0.0022 - val_dense_307_loss: 0.0947 - val_dense_308_loss: 0.4599 - val_dense_309_loss: 0.9218 - val_dense_310_loss: 0.9028 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9724 - val_dense_308_acc: 0.8615 - val_dense_309_acc: 0.7115 - val_dense_310_acc: 0.7195
# Epoch 7/30
# 13400/13400 [==============================] - 54s - loss: 2.0210 - dense_306_loss: 7.0350e-04 - dense_307_loss: 0.0698 - dense_308_loss: 0.3721 - dense_309_loss: 0.7655 - dense_310_loss: 0.8130 - dense_306_acc: 0.9998 - dense_307_acc: 0.9793 - dense_308_acc: 0.8863 - dense_309_acc: 0.7533 - dense_310_acc: 0.7332 - val_loss: 2.3263 - val_dense_306_loss: 0.0025 - val_dense_307_loss: 0.0948 - val_dense_308_loss: 0.4636 - val_dense_309_loss: 0.8748 - val_dense_310_loss: 0.8907 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9726 - val_dense_308_acc: 0.8605 - val_dense_309_acc: 0.7252 - val_dense_310_acc: 0.7192
# Epoch 8/30
# 13400/13400 [==============================] - 59s - loss: 1.8749 - dense_306_loss: 5.3387e-04 - dense_307_loss: 0.0617 - dense_308_loss: 0.3468 - dense_309_loss: 0.7019 - dense_310_loss: 0.7639 - dense_306_acc: 0.9998 - dense_307_acc: 0.9814 - dense_308_acc: 0.8916 - dense_309_acc: 0.7722 - dense_310_acc: 0.7505 - val_loss: 2.3055 - val_dense_306_loss: 0.0023 - val_dense_307_loss: 0.0930 - val_dense_308_loss: 0.4526 - val_dense_309_loss: 0.8693 - val_dense_310_loss: 0.8882 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9732 - val_dense_308_acc: 0.8658 - val_dense_309_acc: 0.7355 - val_dense_310_acc: 0.7203
# Epoch 9/30
# 13400/13400 [==============================] - 58s - loss: 1.7479 - dense_306_loss: 4.8637e-04 - dense_307_loss: 0.0555 - dense_308_loss: 0.3265 - dense_309_loss: 0.6521 - dense_310_loss: 0.7133 - dense_306_acc: 0.9999 - dense_307_acc: 0.9834 - dense_308_acc: 0.9021 - dense_309_acc: 0.7885 - dense_310_acc: 0.7642 - val_loss: 2.2532 - val_dense_306_loss: 0.0028 - val_dense_307_loss: 0.1001 - val_dense_308_loss: 0.4565 - val_dense_309_loss: 0.8324 - val_dense_310_loss: 0.8614 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9694 - val_dense_308_acc: 0.8644 - val_dense_309_acc: 0.7473 - val_dense_310_acc: 0.7283
# Epoch 10/30
# 13400/13400 [==============================] - 61s - loss: 1.6315 - dense_306_loss: 8.6900e-04 - dense_307_loss: 0.0485 - dense_308_loss: 0.3030 - dense_309_loss: 0.6083 - dense_310_loss: 0.6709 - dense_306_acc: 0.9998 - dense_307_acc: 0.9851 - dense_308_acc: 0.9050 - dense_309_acc: 0.8051 - dense_310_acc: 0.7830 - val_loss: 2.2125 - val_dense_306_loss: 0.0026 - val_dense_307_loss: 0.0818 - val_dense_308_loss: 0.4542 - val_dense_309_loss: 0.8309 - val_dense_310_loss: 0.8430 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9758 - val_dense_308_acc: 0.8647 - val_dense_309_acc: 0.7465 - val_dense_310_acc: 0.7333
# Epoch 11/30
# 13400/13400 [==============================] - 55s - loss: 1.5086 - dense_306_loss: 4.2238e-04 - dense_307_loss: 0.0468 - dense_308_loss: 0.2786 - dense_309_loss: 0.5637 - dense_310_loss: 0.6191 - dense_306_acc: 0.9999 - dense_307_acc: 0.9857 - dense_308_acc: 0.9133 - dense_309_acc: 0.8187 - dense_310_acc: 0.7946 - val_loss: 2.2275 - val_dense_306_loss: 0.0030 - val_dense_307_loss: 0.0885 - val_dense_308_loss: 0.4438 - val_dense_309_loss: 0.8174 - val_dense_310_loss: 0.8748 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9738 - val_dense_308_acc: 0.8712 - val_dense_309_acc: 0.7500 - val_dense_310_acc: 0.7233
# Epoch 12/30
# 13400/13400 [==============================] - 54s - loss: 1.4338 - dense_306_loss: 2.0187e-04 - dense_307_loss: 0.0420 - dense_308_loss: 0.2680 - dense_309_loss: 0.5277 - dense_310_loss: 0.5959 - dense_306_acc: 0.9999 - dense_307_acc: 0.9869 - dense_308_acc: 0.9143 - dense_309_acc: 0.8262 - dense_310_acc: 0.8056 - val_loss: 2.2290 - val_dense_306_loss: 0.0031 - val_dense_307_loss: 0.0826 - val_dense_308_loss: 0.4502 - val_dense_309_loss: 0.8340 - val_dense_310_loss: 0.8591 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9762 - val_dense_308_acc: 0.8727 - val_dense_309_acc: 0.7412 - val_dense_310_acc: 0.7312
# Epoch 13/30
# 13400/13400 [==============================] - 50s - loss: 1.3585 - dense_306_loss: 3.4443e-04 - dense_307_loss: 0.0365 - dense_308_loss: 0.2516 - dense_309_loss: 0.5022 - dense_310_loss: 0.5678 - dense_306_acc: 0.9999 - dense_307_acc: 0.9890 - dense_308_acc: 0.9222 - dense_309_acc: 0.8351 - dense_310_acc: 0.8116 - val_loss: 2.2699 - val_dense_306_loss: 0.0030 - val_dense_307_loss: 0.0923 - val_dense_308_loss: 0.4709 - val_dense_309_loss: 0.8432 - val_dense_310_loss: 0.8603 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9739 - val_dense_308_acc: 0.8636 - val_dense_309_acc: 0.7417 - val_dense_310_acc: 0.7291
# Epoch 14/30
# 13400/13400 [==============================] - 51s - loss: 1.2769 - dense_306_loss: 1.4080e-04 - dense_307_loss: 0.0345 - dense_308_loss: 0.2344 - dense_309_loss: 0.4757 - dense_310_loss: 0.5322 - dense_306_acc: 0.9999 - dense_307_acc: 0.9887 - dense_308_acc: 0.9268 - dense_309_acc: 0.8453 - dense_310_acc: 0.8259 - val_loss: 2.2323 - val_dense_306_loss: 0.0035 - val_dense_307_loss: 0.0906 - val_dense_308_loss: 0.4680 - val_dense_309_loss: 0.8110 - val_dense_310_loss: 0.8592 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9765 - val_dense_308_acc: 0.8658 - val_dense_309_acc: 0.7574 - val_dense_310_acc: 0.7335
# Epoch 15/30
# 13400/13400 [==============================] - 50s - loss: 1.2113 - dense_306_loss: 6.0386e-04 - dense_307_loss: 0.0339 - dense_308_loss: 0.2215 - dense_309_loss: 0.4518 - dense_310_loss: 0.5035 - dense_306_acc: 0.9999 - dense_307_acc: 0.9884 - dense_308_acc: 0.9283 - dense_309_acc: 0.8503 - dense_310_acc: 0.8313 - val_loss: 2.2438 - val_dense_306_loss: 0.0034 - val_dense_307_loss: 0.0908 - val_dense_308_loss: 0.4780 - val_dense_309_loss: 0.8267 - val_dense_310_loss: 0.8448 - val_dense_306_acc: 0.9994 - val_dense_307_acc: 0.9756 - val_dense_308_acc: 0.8671 - val_dense_309_acc: 0.7612 - val_dense_310_acc: 0.7442
# Epoch 16/30
# 13400/13400 [==============================] - 48s - loss: 1.1512 - dense_306_loss: 7.0888e-05 - dense_307_loss: 0.0287 - dense_308_loss: 0.2081 - dense_309_loss: 0.4263 - dense_310_loss: 0.4879 - dense_306_acc: 1.0000 - dense_307_acc: 0.9905 - dense_308_acc: 0.9352 - dense_309_acc: 0.8594 - dense_310_acc: 0.8343 - val_loss: 2.2940 - val_dense_306_loss: 0.0031 - val_dense_307_loss: 0.0943 - val_dense_308_loss: 0.4769 - val_dense_309_loss: 0.8363 - val_dense_310_loss: 0.8833 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9739 - val_dense_308_acc: 0.8698 - val_dense_309_acc: 0.7541 - val_dense_310_acc: 0.7347
# Epoch 17/30
# 13400/13400 [==============================] - 54s - loss: 1.1001 - dense_306_loss: 4.3611e-04 - dense_307_loss: 0.0288 - dense_308_loss: 0.2012 - dense_309_loss: 0.4056 - dense_310_loss: 0.4641 - dense_306_acc: 0.9998 - dense_307_acc: 0.9906 - dense_308_acc: 0.9352 - dense_309_acc: 0.8674 - dense_310_acc: 0.8420 - val_loss: 2.3309 - val_dense_306_loss: 0.0044 - val_dense_307_loss: 0.0949 - val_dense_308_loss: 0.4904 - val_dense_309_loss: 0.8510 - val_dense_310_loss: 0.8901 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9753 - val_dense_308_acc: 0.8695 - val_dense_309_acc: 0.7617 - val_dense_310_acc: 0.7335
# Epoch 18/30
# 13400/13400 [==============================] - 55s - loss: 1.0525 - dense_306_loss: 3.7501e-05 - dense_307_loss: 0.0275 - dense_308_loss: 0.1882 - dense_309_loss: 0.3937 - dense_310_loss: 0.4430 - dense_306_acc: 1.0000 - dense_307_acc: 0.9896 - dense_308_acc: 0.9381 - dense_309_acc: 0.8681 - dense_310_acc: 0.8491 - val_loss: 2.3499 - val_dense_306_loss: 0.0040 - val_dense_307_loss: 0.0934 - val_dense_308_loss: 0.5248 - val_dense_309_loss: 0.8669 - val_dense_310_loss: 0.8607 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9758 - val_dense_308_acc: 0.8571 - val_dense_309_acc: 0.7535 - val_dense_310_acc: 0.7465
# Epoch 19/30
# 13400/13400 [==============================] - 53s - loss: 1.0049 - dense_306_loss: 3.0828e-04 - dense_307_loss: 0.0250 - dense_308_loss: 0.1813 - dense_309_loss: 0.3665 - dense_310_loss: 0.4318 - dense_306_acc: 0.9999 - dense_307_acc: 0.9913 - dense_308_acc: 0.9407 - dense_309_acc: 0.8785 - dense_310_acc: 0.8519 - val_loss: 2.3308 - val_dense_306_loss: 0.0041 - val_dense_307_loss: 0.0986 - val_dense_308_loss: 0.5052 - val_dense_309_loss: 0.8606 - val_dense_310_loss: 0.8624 - val_dense_306_acc: 0.9994 - val_dense_307_acc: 0.9747 - val_dense_308_acc: 0.8689 - val_dense_309_acc: 0.7600 - val_dense_310_acc: 0.7491
# Epoch 20/30
# 13400/13400 [==============================] - 50s - loss: 0.9785 - dense_306_loss: 7.1893e-05 - dense_307_loss: 0.0251 - dense_308_loss: 0.1728 - dense_309_loss: 0.3653 - dense_310_loss: 0.4154 - dense_306_acc: 1.0000 - dense_307_acc: 0.9919 - dense_308_acc: 0.9419 - dense_309_acc: 0.8796 - dense_310_acc: 0.8594 - val_loss: 2.3688 - val_dense_306_loss: 0.0044 - val_dense_307_loss: 0.1060 - val_dense_308_loss: 0.5180 - val_dense_309_loss: 0.8698 - val_dense_310_loss: 0.8707 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9718 - val_dense_308_acc: 0.8627 - val_dense_309_acc: 0.7648 - val_dense_310_acc: 0.7464
# Epoch 21/30
# 13400/13400 [==============================] - 50s - loss: 0.9146 - dense_306_loss: 8.2832e-05 - dense_307_loss: 0.0218 - dense_308_loss: 0.1677 - dense_309_loss: 0.3325 - dense_310_loss: 0.3926 - dense_306_acc: 0.9999 - dense_307_acc: 0.9922 - dense_308_acc: 0.9433 - dense_309_acc: 0.8895 - dense_310_acc: 0.8651 - val_loss: 2.3871 - val_dense_306_loss: 0.0048 - val_dense_307_loss: 0.1046 - val_dense_308_loss: 0.5261 - val_dense_309_loss: 0.8990 - val_dense_310_loss: 0.8527 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9752 - val_dense_308_acc: 0.8629 - val_dense_309_acc: 0.7533 - val_dense_310_acc: 0.7515
# Epoch 22/30
# 13400/13400 [==============================] - 51s - loss: 0.8889 - dense_306_loss: 7.2925e-05 - dense_307_loss: 0.0234 - dense_308_loss: 0.1602 - dense_309_loss: 0.3200 - dense_310_loss: 0.3853 - dense_306_acc: 1.0000 - dense_307_acc: 0.9919 - dense_308_acc: 0.9449 - dense_309_acc: 0.8950 - dense_310_acc: 0.8679 - val_loss: 2.4589 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1061 - val_dense_308_loss: 0.5288 - val_dense_309_loss: 0.9315 - val_dense_310_loss: 0.8877 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9742 - val_dense_308_acc: 0.8658 - val_dense_309_acc: 0.7521 - val_dense_310_acc: 0.7497
# Epoch 23/30
# 13400/13400 [==============================] - 55s - loss: 0.8577 - dense_306_loss: 3.6727e-05 - dense_307_loss: 0.0210 - dense_308_loss: 0.1484 - dense_309_loss: 0.3204 - dense_310_loss: 0.3678 - dense_306_acc: 1.0000 - dense_307_acc: 0.9925 - dense_308_acc: 0.9500 - dense_309_acc: 0.8934 - dense_310_acc: 0.8760 - val_loss: 2.4953 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1108 - val_dense_308_loss: 0.5502 - val_dense_309_loss: 0.9141 - val_dense_310_loss: 0.9153 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9735 - val_dense_308_acc: 0.8633 - val_dense_309_acc: 0.7594 - val_dense_310_acc: 0.7488
# Epoch 24/30
# 13400/13400 [==============================] - 54s - loss: 0.8266 - dense_306_loss: 2.7238e-04 - dense_307_loss: 0.0227 - dense_308_loss: 0.1448 - dense_309_loss: 0.2971 - dense_310_loss: 0.3618 - dense_306_acc: 0.9999 - dense_307_acc: 0.9918 - dense_308_acc: 0.9510 - dense_309_acc: 0.9016 - dense_310_acc: 0.8776 - val_loss: 2.5894 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1115 - val_dense_308_loss: 0.5619 - val_dense_309_loss: 0.9471 - val_dense_310_loss: 0.9640 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9752 - val_dense_308_acc: 0.8630 - val_dense_309_acc: 0.7541 - val_dense_310_acc: 0.7341
# Epoch 25/30
# 13400/13400 [==============================] - 53s - loss: 0.7964 - dense_306_loss: 1.5013e-04 - dense_307_loss: 0.0202 - dense_308_loss: 0.1373 - dense_309_loss: 0.2792 - dense_310_loss: 0.3595 - dense_306_acc: 0.9999 - dense_307_acc: 0.9935 - dense_308_acc: 0.9512 - dense_309_acc: 0.9051 - dense_310_acc: 0.8763 - val_loss: 2.6151 - val_dense_306_loss: 0.0048 - val_dense_307_loss: 0.1176 - val_dense_308_loss: 0.5699 - val_dense_309_loss: 0.9676 - val_dense_310_loss: 0.9552 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9755 - val_dense_308_acc: 0.8689 - val_dense_309_acc: 0.7509 - val_dense_310_acc: 0.7424
# Epoch 26/30
# 13400/13400 [==============================] - 51s - loss: 0.7765 - dense_306_loss: 9.6524e-05 - dense_307_loss: 0.0181 - dense_308_loss: 0.1365 - dense_309_loss: 0.2846 - dense_310_loss: 0.3372 - dense_306_acc: 0.9999 - dense_307_acc: 0.9929 - dense_308_acc: 0.9524 - dense_309_acc: 0.9055 - dense_310_acc: 0.8843 - val_loss: 2.5755 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1161 - val_dense_308_loss: 0.5760 - val_dense_309_loss: 0.9367 - val_dense_310_loss: 0.9418 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9753 - val_dense_308_acc: 0.8664 - val_dense_309_acc: 0.7627 - val_dense_310_acc: 0.7453
# Epoch 27/30
# 13400/13400 [==============================] - 52s - loss: 0.7428 - dense_306_loss: 4.1294e-04 - dense_307_loss: 0.0178 - dense_308_loss: 0.1244 - dense_309_loss: 0.2710 - dense_310_loss: 0.3292 - dense_306_acc: 0.9999 - dense_307_acc: 0.9933 - dense_308_acc: 0.9577 - dense_309_acc: 0.9081 - dense_310_acc: 0.8882 - val_loss: 2.7139 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1225 - val_dense_308_loss: 0.5895 - val_dense_309_loss: 1.0378 - val_dense_310_loss: 0.9592 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9727 - val_dense_308_acc: 0.8650 - val_dense_309_acc: 0.7455 - val_dense_310_acc: 0.7483
# Epoch 28/30
# 13400/13400 [==============================] - 52s - loss: 0.7196 - dense_306_loss: 3.3982e-05 - dense_307_loss: 0.0195 - dense_308_loss: 0.1173 - dense_309_loss: 0.2701 - dense_310_loss: 0.3126 - dense_306_acc: 1.0000 - dense_307_acc: 0.9934 - dense_308_acc: 0.9596 - dense_309_acc: 0.9050 - dense_310_acc: 0.8964 - val_loss: 2.7062 - val_dense_306_loss: 0.0049 - val_dense_307_loss: 0.1174 - val_dense_308_loss: 0.5969 - val_dense_309_loss: 1.0036 - val_dense_310_loss: 0.9834 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9733 - val_dense_308_acc: 0.8677 - val_dense_309_acc: 0.7545 - val_dense_310_acc: 0.7442
# Epoch 29/30
# 13400/13400 [==============================] - 53s - loss: 0.7111 - dense_306_loss: 1.3562e-04 - dense_307_loss: 0.0204 - dense_308_loss: 0.1199 - dense_309_loss: 0.2583 - dense_310_loss: 0.3123 - dense_306_acc: 0.9999 - dense_307_acc: 0.9924 - dense_308_acc: 0.9601 - dense_309_acc: 0.9122 - dense_310_acc: 0.8931 - val_loss: 2.7078 - val_dense_306_loss: 0.0052 - val_dense_307_loss: 0.1192 - val_dense_308_loss: 0.6136 - val_dense_309_loss: 1.0063 - val_dense_310_loss: 0.9635 - val_dense_306_acc: 0.9995 - val_dense_307_acc: 0.9739 - val_dense_308_acc: 0.8671 - val_dense_309_acc: 0.7550 - val_dense_310_acc: 0.7489
# Epoch 30/30
# 13400/13400 [==============================] - 57s - loss: 0.6765 - dense_306_loss: 6.3033e-06 - dense_307_loss: 0.0175 - dense_308_loss: 0.1068 - dense_309_loss: 0.2556 - dense_310_loss: 0.2966 - dense_306_acc: 1.0000 - dense_307_acc: 0.9935 - dense_308_acc: 0.9636 - dense_309_acc: 0.9134 - dense_310_acc: 0.8986 - val_loss: 2.8141 - val_dense_306_loss: 0.0047 - val_dense_307_loss: 0.1320 - val_dense_308_loss: 0.6434 - val_dense_309_loss: 1.0401 - val_dense_310_loss: 0.9939 - val_dense_306_acc: 0.9997 - val_dense_307_acc: 0.9727 - val_dense_308_acc: 0.8571 - val_dense_309_acc: 0.7512 - val_dense_310_acc: 0.7444

# %%
model.save('cnn_recog.h5')

# %%
idx=20
fig,ax = plt.subplots(1)
im = sv_validation[idx]
print(im.shape)
y_pred = model.predict(im.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1),batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
plt.imshow(im.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
# Out:
# (60, 60, 1)
# 00021

# %% [markdown]
# ### Question 4
# _Describe how you set up the training and testing data for your model. How does the model perform on a realistic dataset?_

# %% [markdown]
# **Answer:**
# I have used the information abot the digit boxes to infer the coordinates of the box wrapping the whole number. I have expanded the obtained coordinates to get a 30% wider box I used to crop the image. To resulting images are smaller and centered on the number. I then resize them to the desired 28x28 size which is a more suitable size for a network that has to be trained on a laptop like mine. Another reduction has been made on the number of channels, from 3 RGB to 1 Gray, by averaging the RGB contributions.

# %% [markdown]
# ### Question 5
# _What changes did you have to make, if any, to achieve "good" results? Were there any options you explored that made the results worse?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 6
# _What were your initial and final results with testing on a realistic dataset? Do you believe your model is doing a good enough job at classifying numbers correctly?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ----
# ## Step 3: Test a Model on Newly-Captured Images
#
# Take several pictures of numbers that you find around you (at least five), and run them through your classifier on your computer to produce example results. Alternatively (optionally), you can try using OpenCV / SimpleCV / Pygame to capture live images from a webcam and run those through your classifier.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
BIG=100
SV_IMG_SIZE=60
shot_folder="./"
files = ["shot1.jpg","shot2.jpg","shot3.jpg","shot4.jpg","shot5.jpg"]
fig,axarr = plt.subplots(2,3)
for idx,name in enumerate(files):
    fullname = os.path.join(shot_folder, name)
    img = Image.open(fullname)
    axarr[idx/3][idx%3].imshow(img)
    axarr[idx/3][idx%3].axis('off')
axarr[1][2].axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
filename = 'shot1.jpg'
fullname = os.path.join(shot_folder, filename)
img = Image.open(fullname)
img = img.resize((BIG,BIG), Image.ANTIALIAS)
img = img.crop([45,40,70,70])
img = img.resize((SV_IMG_SIZE,SV_IMG_SIZE), Image.ANTIALIAS)

array = np.asarray(img)
array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,3)).astype(np.float32)
na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE],dtype=int)
for x in range (array.shape[0]):
    for y in range (array.shape[1]):
        na[x][y]=np.average(array[x][y][:])
array = na.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1)
array = (array/125.5)-1
plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
y_pred = model.predict(array,batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
# Out:
# 00024

# %%
filename = 'shot2.jpg'
fullname = os.path.join(shot_folder, filename)
img = Image.open(fullname)
img = img.resize((BIG,BIG), Image.ANTIALIAS)
img = img.crop([16,20,45,40])
img = img.resize((SV_IMG_SIZE,SV_IMG_SIZE), Image.ANTIALIAS)
array = np.asarray(img)
array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,3)).astype(np.float32)
na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE],dtype=int)
for x in range (array.shape[0]):
    for y in range (array.shape[1]):
        na[x][y]=np.average(array[x][y][:])
array = na.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1)
array = (array/125.5)-1
plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
y_pred = model.predict(array,batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
# Out:
# 00392

# %%
filename = 'shot3.jpg'
fullname = os.path.join(shot_folder, filename)
img = Image.open(fullname)
img = img.resize((BIG,BIG), Image.ANTIALIAS)
img = img.crop([20,45,50,80])
img = img.resize((SV_IMG_SIZE,SV_IMG_SIZE), Image.ANTIALIAS)
array = np.asarray(img)
array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,3)).astype(np.float32)
na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE],dtype=int)
for x in range (array.shape[0]):
    for y in range (array.shape[1]):
        na[x][y]=np.average(array[x][y][:])
array = na.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1)
array = (array/125.5)-1
plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
y_pred = model.predict(array,batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
# Out:
# 00012

# %%
filename = 'shot4.jpg'
fullname = os.path.join(shot_folder, filename)
img = Image.open(fullname)
img = img.resize((BIG,BIG), Image.ANTIALIAS)
img = img.crop([55,25,90,60])
img = img.resize((SV_IMG_SIZE,SV_IMG_SIZE), Image.ANTIALIAS)
array = np.asarray(img)
array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,3)).astype(np.float32)
na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE],dtype=int)
for x in range (array.shape[0]):
    for y in range (array.shape[1]):
        na[x][y]=np.average(array[x][y][:])
array = na.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1)
array = (array/125.5)-1
plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
y_pred = model.predict(array,batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
# Out:
# 000410

# %%
filename = 'shot5.jpg'
fullname = os.path.join(shot_folder, filename)
img = Image.open(fullname)
img = img.resize((BIG,BIG), Image.ANTIALIAS)
img = img.crop([25,25,60,60])
img = img.resize((SV_IMG_SIZE,SV_IMG_SIZE), Image.ANTIALIAS)
array = np.asarray(img)
array =  array.reshape((SV_IMG_SIZE,SV_IMG_SIZE,3)).astype(np.float32)
na = np.zeros([SV_IMG_SIZE,SV_IMG_SIZE],dtype=int)
for x in range (array.shape[0]):
    for y in range (array.shape[1]):
        na[x][y]=np.average(array[x][y][:])
array = na.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1)
array = (array/125.5)-1
plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
y_pred = model.predict(array,batch_size=1,verbose=0)
for a in y_pred:
    values = a[0].tolist()
    print(values.index(max(values)),end="")
# Out:
# 00025

# %% [markdown]
# ### Question 7
# _Choose five candidate images of numbers you took from around you and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 8
# _Is your model able to perform equally well on captured pictures or a live camera stream when compared to testing on the realistic dataset?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Optional: Question 9
# _If necessary, provide documentation for how an interface was built for your model to load and classify newly-acquired images._

# %% [markdown]
# **Answer:** Leave blank if you did not complete this part.

# %% [markdown]
# ----
# ### Step 4: Explore an Improvement for a Model
#
# There are many things you can do once you have the basic classifier in place. One example would be to also localize where the numbers are on the image. The SVHN dataset provides bounding boxes that you can tune to train a localizer. Train a regression loss to the coordinates of the bounding box, and then test it.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
from sklearn.model_selection import train_test_split
svb_train, svb_validation, svbt_labels, svbv_labels = train_test_split(sv_images, nboxes, test_size=0.33, random_state=42)

# %%
try:
    model = load_model('box_cnn.h5')
except:
    model = None

x = Input((SV_IMG_SIZE, SV_IMG_SIZE,SV_CHANNELS))
y = Convolution2D(8, 3, 3, activation="relu", border_mode="same")(x)
y = MaxPooling2D((2, 2))(y)
y = Convolution2D(16, 3, 3, border_mode="same", activation="relu")(y)
y = MaxPooling2D((2, 2))(y)
y = Flatten()(y)
y = Dense(128, activation="relu")(y)

boxX = Dense(1)(y)
boxY = Dense(1)(y)
boxWidth = Dense(1)(y)
boxHeight = Dense(1)(y)

if not None:
    model = Model(input=x, output=[boxX, boxY, boxWidth,boxHeight])
    model.compile(optimizer='adam',
          loss='mean_squared_error',
          metrics=['mean_squared_error'])


svb_train_labels = [np.array([i[0] for i in svbt_labels]),
                             np.array([i[1] for i in svbt_labels]),
                             np.array([i[2] for i in svbt_labels]),
                             np.array([i[3] for i in svbt_labels])]
                           
svb_validation_labels = [np.array([i[0] for i in svbv_labels]),
                                 np.array([i[1] for i in svbv_labels]),
                                 np.array([i[2] for i in svbv_labels]),
                                 np.array([i[3] for i in svbv_labels])]


model.fit(svb_train,svb_train_labels
          , nb_epoch=10, batch_size=32,
         validation_data=(svb_validation, svb_validation_labels))
# Out:
# Train on 13400 samples, validate on 6600 samples
# Epoch 1/10
# 13400/13400 [==============================] - 27s - loss: 61.5975 - dense_205_loss: 20.1622 - dense_206_loss: 8.3660 - dense_207_loss: 15.8820 - dense_208_loss: 17.1874 - dense_205_mean_squared_error: 20.1622 - dense_206_mean_squared_error: 8.3660 - dense_207_mean_squared_error: 15.8820 - dense_208_mean_squared_error: 17.1874 - val_loss: 19.1559 - val_dense_205_loss: 9.4135 - val_dense_206_loss: 1.5417 - val_dense_207_loss: 6.3296 - val_dense_208_loss: 1.8711 - val_dense_205_mean_squared_error: 9.4135 - val_dense_206_mean_squared_error: 1.5417 - val_dense_207_mean_squared_error: 6.3296 - val_dense_208_mean_squared_error: 1.8711
# Epoch 2/10
# 13400/13400 [==============================] - 25s - loss: 17.8984 - dense_205_loss: 8.7236 - dense_206_loss: 1.4139 - dense_207_loss: 6.0851 - dense_208_loss: 1.6757 - dense_205_mean_squared_error: 8.7236 - dense_206_mean_squared_error: 1.4139 - dense_207_mean_squared_error: 6.0851 - dense_208_mean_squared_error: 1.6757 - val_loss: 16.1596 - val_dense_205_loss: 7.4757 - val_dense_206_loss: 1.3375 - val_dense_207_loss: 5.6343 - val_dense_208_loss: 1.7121 - val_dense_205_mean_squared_error: 7.4757 - val_dense_206_mean_squared_error: 1.3375 - val_dense_207_mean_squared_error: 5.6343 - val_dense_208_mean_squared_error: 1.7121
# Epoch 3/10
# 13400/13400 [==============================] - 25s - loss: 15.1460 - dense_205_loss: 7.1150 - dense_206_loss: 1.2228 - dense_207_loss: 5.3450 - dense_208_loss: 1.4632 - dense_205_mean_squared_error: 7.1150 - dense_206_mean_squared_error: 1.2228 - dense_207_mean_squared_error: 5.3450 - dense_208_mean_squared_error: 1.4632 - val_loss: 15.7416 - val_dense_205_loss: 7.1586 - val_dense_206_loss: 2.2102 - val_dense_207_loss: 4.8921 - val_dense_208_loss: 1.4807 - val_dense_205_mean_squared_error: 7.1586 - val_dense_206_mean_squared_error: 2.2102 - val_dense_207_mean_squared_error: 4.8921 - val_dense_208_mean_squared_error: 1.4807
# Epoch 4/10
# 13400/13400 [==============================] - 26s - loss: 13.8006 - dense_205_loss: 6.3137 - dense_206_loss: 1.1879 - dense_207_loss: 4.9480 - dense_208_loss: 1.3509 - dense_205_mean_squared_error: 6.3137 - dense_206_mean_squared_error: 1.1879 - dense_207_mean_squared_error: 4.9480 - dense_208_mean_squared_error: 1.3509 - val_loss: 12.7476 - val_dense_205_loss: 5.6471 - val_dense_206_loss: 1.3088 - val_dense_207_loss: 4.5701 - val_dense_208_loss: 1.2216 - val_dense_205_mean_squared_error: 5.6471 - val_dense_206_mean_squared_error: 1.3088 - val_dense_207_mean_squared_error: 4.5701 - val_dense_208_mean_squared_error: 1.2216
# Epoch 5/10
# 13400/13400 [==============================] - 26s - loss: 12.7133 - dense_205_loss: 5.8334 - dense_206_loss: 1.1190 - dense_207_loss: 4.5314 - dense_208_loss: 1.2295 - dense_205_mean_squared_error: 5.8334 - dense_206_mean_squared_error: 1.1190 - dense_207_mean_squared_error: 4.5314 - dense_208_mean_squared_error: 1.2295 - val_loss: 11.9254 - val_dense_205_loss: 5.2674 - val_dense_206_loss: 1.0433 - val_dense_207_loss: 4.3784 - val_dense_208_loss: 1.2363 - val_dense_205_mean_squared_error: 5.2674 - val_dense_206_mean_squared_error: 1.0433 - val_dense_207_mean_squared_error: 4.3784 - val_dense_208_mean_squared_error: 1.2363
# Epoch 6/10
# 13400/13400 [==============================] - 27s - loss: 12.0064 - dense_205_loss: 5.4250 - dense_206_loss: 1.0867 - dense_207_loss: 4.3296 - dense_208_loss: 1.1651 - dense_205_mean_squared_error: 5.4250 - dense_206_mean_squared_error: 1.0867 - dense_207_mean_squared_error: 4.3296 - dense_208_mean_squared_error: 1.1651 - val_loss: 11.2709 - val_dense_205_loss: 5.0099 - val_dense_206_loss: 1.0439 - val_dense_207_loss: 4.1220 - val_dense_208_loss: 1.0951 - val_dense_205_mean_squared_error: 5.0099 - val_dense_206_mean_squared_error: 1.0439 - val_dense_207_mean_squared_error: 4.1220 - val_dense_208_mean_squared_error: 1.0951
# Epoch 7/10
# 13400/13400 [==============================] - 26s - loss: 11.2302 - dense_205_loss: 5.0763 - dense_206_loss: 1.0334 - dense_207_loss: 4.0176 - dense_208_loss: 1.1028 - dense_205_mean_squared_error: 5.0763 - dense_206_mean_squared_error: 1.0334 - dense_207_mean_squared_error: 4.0176 - dense_208_mean_squared_error: 1.1028 - val_loss: 10.5534 - val_dense_205_loss: 4.6982 - val_dense_206_loss: 0.9960 - val_dense_207_loss: 3.8242 - val_dense_208_loss: 1.0351 - val_dense_205_mean_squared_error: 4.6982 - val_dense_206_mean_squared_error: 0.9960 - val_dense_207_mean_squared_error: 3.8242 - val_dense_208_mean_squared_error: 1.0351
# Epoch 8/10
# 13400/13400 [==============================] - 27s - loss: 10.5375 - dense_205_loss: 4.7444 - dense_206_loss: 0.9950 - dense_207_loss: 3.7612 - dense_208_loss: 1.0369 - dense_205_mean_squared_error: 4.7444 - dense_206_mean_squared_error: 0.9950 - dense_207_mean_squared_error: 3.7612 - dense_208_mean_squared_error: 1.0369 - val_loss: 10.3502 - val_dense_205_loss: 4.4573 - val_dense_206_loss: 1.1748 - val_dense_207_loss: 3.6088 - val_dense_208_loss: 1.1093 - val_dense_205_mean_squared_error: 4.4573 - val_dense_206_mean_squared_error: 1.1748 - val_dense_207_mean_squared_error: 3.6088 - val_dense_208_mean_squared_error: 1.1093
# Epoch 9/10
# 13400/13400 [==============================] - 27s - loss: 10.0891 - dense_205_loss: 4.5310 - dense_206_loss: 0.9679 - dense_207_loss: 3.5782 - dense_208_loss: 1.0120 - dense_205_mean_squared_error: 4.5310 - dense_206_mean_squared_error: 0.9679 - dense_207_mean_squared_error: 3.5782 - dense_208_mean_squared_error: 1.0120 - val_loss: 9.8475 - val_dense_205_loss: 4.4045 - val_dense_206_loss: 0.9935 - val_dense_207_loss: 3.4649 - val_dense_208_loss: 0.9846 - val_dense_205_mean_squared_error: 4.4045 - val_dense_206_mean_squared_error: 0.9935 - val_dense_207_mean_squared_error: 3.4649 - val_dense_208_mean_squared_error: 0.9846
# Epoch 10/10
# 13400/13400 [==============================] - 27s - loss: 9.5893 - dense_205_loss: 4.2989 - dense_206_loss: 0.9132 - dense_207_loss: 3.4322 - dense_208_loss: 0.9450 - dense_205_mean_squared_error: 4.2989 - dense_206_mean_squared_error: 0.9132 - dense_207_mean_squared_error: 3.4322 - dense_208_mean_squared_error: 0.9450 - val_loss: 9.9230 - val_dense_205_loss: 4.1194 - val_dense_206_loss: 1.0762 - val_dense_207_loss: 3.8103 - val_dense_208_loss: 0.9171 - val_dense_205_mean_squared_error: 4.1194 - val_dense_206_mean_squared_error: 1.0762 - val_dense_207_mean_squared_error: 3.8103 - val_dense_208_mean_squared_error: 0.9171

# %%
model.save('box_cnn.h5')

# %%
idx=390
fig,ax = plt.subplots(1)
im = svb_validation[idx]
y_pred = model.predict(im.reshape(1,SV_IMG_SIZE,SV_IMG_SIZE,1),batch_size=1,verbose=0)
ax.imshow(im.reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
box = y_pred
rect = patches.Rectangle((box[0][0][0],box[1][0][0]),box[2][0][0],box[3][0][0],linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
print(y_pred)
# Out:
# [array([[ 17.28009987]], dtype=float32), array([[ 14.50288486]], dtype=float32), array([[ 20.50886917]], dtype=float32), array([[ 21.95881844]], dtype=float32)]

# %%
fig,ax = plt.subplots(1)
print(array.shape)
#plt.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE,SV_CHANNELS))
y_pred = model.predict(array,batch_size=1,verbose=0)
ax.imshow(array.reshape(SV_IMG_SIZE,SV_IMG_SIZE))
#plt.imshow(sv_images[idx].reshape(SV_IMG_SIZE,SV_IMG_SIZE),cmap='gray')
box = y_pred
rect = patches.Rectangle((box[0][0][0],box[1][0][0]),box[2][0][0],box[3][0][0],linewidth=1,edgecolor='r',facecolor='none')
#rect = patches.Rectangle((5.145,5.05),17.08,17.013)
ax.add_patch(rect)
print(y_pred)
# Out:
# (1, 50, 50, 1)
# [array([[ 21.97393608]], dtype=float32), array([[ 18.2714653]], dtype=float32), array([[ 20.39871788]], dtype=float32), array([[ 20.50427628]], dtype=float32)]

# %% [markdown]
# ### Question 10
# _How well does your model localize numbers on the testing set from the realistic dataset? Do your classification results change at all with localization included?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 11
# _Test the localization function on the images you captured in **Step 3**. Does the model accurately calculate a bounding box for the numbers in the images you found? If you did not use a graphical interface, you may need to investigate the bounding boxes by hand._ Provide an example of the localization created on a captured image.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ----
# ## Optional Step 5: Build an Application or Program for a Model
# Take your project one step further. If you're interested, look to build an Android application or even a more robust Python program that can interface with input images and display the classified numbers and even the bounding boxes. You can for example try to build an augmented reality app by overlaying your answer on the image like the [Word Lens](https://en.wikipedia.org/wiki/Word_Lens) app does.
#
# Loading a TensorFlow model into a camera app on Android is demonstrated in the [TensorFlow Android demo app](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/android), which you can simply modify.
#
# If you decide to explore this optional route, be sure to document your interface and implementation, along with significant results you find. You can see the additional rubric items that you could be evaluated on by [following this link](https://review.udacity.com/#!/rubrics/413/view).

# %% [markdown]
# ### Optional Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your optional code implementation goes here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Documentation
# Provide additional documentation sufficient for detailing the implementation of the Android application or Python program for visualizing the classification of numbers in images. It should be clear how the program or application works. Demonstrations should be provided.

# %% [markdown]
# _Write your documentation here._

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
